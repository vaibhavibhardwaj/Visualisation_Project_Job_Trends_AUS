# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

gender_stats = pd.read_csv("5fbbf996-3ab2-44be-a16f-fcbc4dfd9033_Data.csv")
gender_stats2 = pd.read_csv("33dfb901-ffa8-4489-ad39-275afba2be5a_Data.csv")
gender_stats2.head()
gender_stats.head()
gender_stats2 = gender_stats2.drop(["Country Name","Country Code"], axis = 1)
gender_stats2 = gender_stats2.drop([570,571,572,574,573])
gender_stats = gender_stats.drop(["Country Code","Country Name"], axis = 1)
gender_stats = gender_stats.drop([60,61,62,64,63])
gender_stats = gender_stats.replace(to_replace= np.nan,value = 0)
gender_stats.head()
#gender_stats.to_csv (r'C:\Users\vaibh\Downloads\Data_Extract_From_Gender_Statistics (1)\gender_stat.csv', index = False, header=True)
#gender_stats["Series Name"]
# Out:
#      Time Time Code  \
# 0  1960.0    YR1960
# 1  1961.0    YR1961
# 2  1962.0    YR1962
# 3  1963.0    YR1963
# 4  1964.0    YR1964
#
#   Access to anti-retroviral drugs, female (%) [SH.HIV.ARTC.FE.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Access to anti-retroviral drugs, male (%) [SH.HIV.ARTC.MA.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+) [FX.OWN.TOTL.FE.ZS]  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Series Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-3424b3966b0c> in <module>
# ----> 1 gender_stats["Series Name"]
# ...

# %%
gender_stats2.head()
gender_stats35=gender_stats2['Series Code']
gender_stats35
# Out:
# 0           SH.HIV.ARTC.FE.ZS
# 1           SH.HIV.ARTC.MA.ZS
# 2           FX.OWN.TOTL.FE.ZS
# 3           FX.OWN.TOTL.MA.ZS
# 4              SE.PRM.TENR.FE
# 5              SE.PRM.TENR.MA
# 6                 SP.ADO.TFRT
# 7              SP.DYN.SMAM.FE
# 8              SP.DYN.SMAM.MA
# 9                 SP.POP.DPND
# 10          SP.POP.AG00.FE.IN
# 11          SP.POP.AG00.MA.IN
# 12          SP.POP.AG01.FE.IN
# 13          SP.POP.AG01.MA.IN
# 14          SP.POP.AG02.FE.IN
# 15          SP.POP.AG02.MA.IN
# 16          SP.POP.AG03.FE.IN
# 17          SP.POP.AG03.MA.IN
# 18          SP.POP.AG04.FE.IN
# 19          SP.POP.AG04.MA.IN
# 20          SP.POP.AG05.FE.IN
# 21          SP.POP.AG05.MA.IN
# 22             SP.DYN.CBRT.IN
# 23             SH.STA.BRTC.ZS
# 24     SH.DTH.COMM.1534.FE.ZS
# 25     SH.DTH.COMM.1534.MA.ZS
# 26     SH.DTH.COMM.3559.FE.ZS
# 27     SH.DTH.COMM.3559.MA.ZS
# 28     SH.DTH.INJR.1534.FE.ZS
# 29     SH.DTH.INJR.1534.MA.ZS
#                 ...
# ...

# %%
 gender_stats3 = gender_stats[["Time","Employers, female (% of female employment) (modeled ILO estimate) [SL.EMP.MPYR.FE.ZS]",
                            "Employment in agriculture, female (% of female employment) (modeled ILO estimate) [SL.AGR.EMPL.FE.ZS]",
                             "Employment in industry, female (% of female employment) (modeled ILO estimate) [SL.IND.EMPL.FE.ZS]",
                             "Employment in services, female (% of female employment) (modeled ILO estimate) [SL.SRV.EMPL.FE.ZS]"]]
gender_stats3["Sex"]= "Female"
gender_stats3 = gender_stats3.drop(gender_stats3.index[0:31])
gender_stats3 = gender_stats3.reset_index()
gender_stats3 = gender_stats3.drop(["index"], axis = 1)
gender_stats3.head()
agf=gender_stats3[["Time","Sex","Employment in agriculture, female (% of female employment) (modeled ILO estimate) [SL.AGR.EMPL.FE.ZS]"]]
agf["Type"]= "agriculture"
agf.rename(columns = {"Employment in agriculture, female (% of female employment) (modeled ILO estimate) [SL.AGR.EMPL.FE.ZS]":"Percentage"},inplace = True)
agf

sf=gender_stats3[["Time","Sex","Employment in services, female (% of female employment) (modeled ILO estimate) [SL.SRV.EMPL.FE.ZS]"]]
sf["Type"]= "services"
sf.rename(columns = {"Employment in services, female (% of female employment) (modeled ILO estimate) [SL.SRV.EMPL.FE.ZS]":"Percentage"},inplace = True)
sf

inf=gender_stats3[["Time","Sex","Employment in industry, female (% of female employment) (modeled ILO estimate) [SL.IND.EMPL.FE.ZS]"]]
inf["Type"]= "industry"
inf.rename(columns = {"Employment in industry, female (% of female employment) (modeled ILO estimate) [SL.IND.EMPL.FE.ZS]":"Percentage"},inplace = True)
inf

emp_female = pd.concat([agf,sf,inf])
emp_female

# %%
gender_stats3m = gender_stats[["Time",
                              "Employers, male (% of male employment) (modeled ILO estimate) [SL.EMP.MPYR.MA.ZS]",
                              "Employment in agriculture, male (% of male employment) (modeled ILO estimate) [SL.AGR.EMPL.MA.ZS]",
                             "Employment in industry, male (% of male employment) (modeled ILO estimate) [SL.IND.EMPL.MA.ZS]",
                            "Employment in services, male (% of male employment) (modeled ILO estimate) [SL.SRV.EMPL.MA.ZS]"]]
gender_stats3m["Sex"]= "Male"
gender_stats3m = gender_stats3m.drop(gender_stats3m.index[0:31])
gender_stats3m = gender_stats3m.reset_index()
gender_stats3m = gender_stats3m.drop(["index"], axis = 1)
gender_stats3m.head()

agf=gender_stats3m[["Time","Sex","Employment in agriculture, male (% of male employment) (modeled ILO estimate) [SL.AGR.EMPL.MA.ZS]"]]
agf["Type"]= "agriculture"
agf.rename(columns = {"Employment in agriculture, male (% of male employment) (modeled ILO estimate) [SL.AGR.EMPL.MA.ZS]":"Percentage"},inplace = True)
agf

sf=gender_stats3m[["Time","Sex","Employment in services, male (% of male employment) (modeled ILO estimate) [SL.SRV.EMPL.MA.ZS]"]]
sf["Type"]= "services"
sf.rename(columns = {"Employment in services, male (% of male employment) (modeled ILO estimate) [SL.SRV.EMPL.MA.ZS]":"Percentage"},inplace = True)
sf

inf=gender_stats3m[["Time","Sex","Employment in industry, male (% of male employment) (modeled ILO estimate) [SL.IND.EMPL.MA.ZS]"]]
inf["Type"]= "industry"
inf.rename(columns = {"Employment in industry, male (% of male employment) (modeled ILO estimate) [SL.IND.EMPL.MA.ZS]":"Percentage"},inplace = True)
inf

emp_male = pd.concat([agf,sf,inf])
emp_male
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
emp_mf = pd.concat([emp_female,emp_male])
emp_mf= emp_mf.reset_index()
emp_mf = emp_mf.drop("index",axis = 1)
emp_mf
emp_mf.to_csv (r'C:\Users\vaibh\Documents\expo_project\emp_mf.csv', index = False, header=True)

# %%
job_stats = pd.read_csv("cf4b91ce-8b01-4ccf-8294-43d5cb2d2550_Data.csv") 
job_stat2 = pd.read_csv("746043e4-2172-4863-b6b3-430837affb80_Data.csv") #with series
job_stat2 = job_stat2.drop(["Country Name","Country Code"], axis = 1)
job_stat2 = job_stat2.drop([166,167,168,169,170])
job_stats = job_stats.drop(["Country Code","Country Name"], axis = 1)
job_stats = job_stats.drop([27,28,29,30,31])
job_stats = job_stats.replace(to_replace= np.nan,value = 0)
job_stat2.head()
#job_stats.to_csv (r'C:\Users\vaibh\Downloads\Data_Extract_From_Jobs (1)\job_stat.csv', index = False, header=True)
job_stats.head()
# Out:
#      Time Time Code  Access to electricity (% of population) [EG.ELC.ACCS.ZS]  \
# 0  1990.0    YR1990                                              100.0
# 1  1991.0    YR1991                                              100.0
# 2  1992.0    YR1992                                              100.0
# 3  1993.0    YR1993                                              100.0
# 4  1994.0    YR1994                                              100.0
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19) [SP.ADO.TFRT]  \
# 0                                            20.9650
# 1                                            20.9200
# 2                                            20.8750
# 3                                            20.5906
# 4                                            20.3062
#
#    Age dependency ratio (% of working-age population) [SP.POP.DPND]  \
# 0                                          49.592036
# 1                                          49.577589
# ...

# %%
jobs_statsm= job_stats[["Time",
                        "Unemployment with advanced education, male (% of male labor force with advanced education) [SL.UEM.ADVN.MA.ZS]",
                        "Unemployment with intermediate education, male (% of male labor force with intermediate education) [SL.UEM.INTM.MA.ZS]"]]

jobs_statsf = job_stats[["Time",
                        "Unemployment with advanced education, female (% of female labor force with advanced education) [SL.UEM.ADVN.FE.ZS]",
                        "Unemployment with intermediate education, female (% of female labor force with intermediate education) [SL.UEM.INTM.FE.ZS]"]]
jobs_statsm["Sex"]= "Male"
jobs_statsf["Sex"]= "Female"


am=jobs_statsm[["Time","Sex","Unemployment with advanced education, male (% of male labor force with advanced education) [SL.UEM.ADVN.MA.ZS]"]]
am["Education"]= "advanced"
am.rename(columns = {"Unemployment with advanced education, male (% of male labor force with advanced education) [SL.UEM.ADVN.MA.ZS]":"Percentage unemployment"},inplace = True)
am


in_m=jobs_statsm[["Time","Sex","Unemployment with intermediate education, male (% of male labor force with intermediate education) [SL.UEM.INTM.MA.ZS]"]]
in_m["Education"]= "intermediate"
in_m.rename(columns = {"Unemployment with intermediate education, male (% of male labor force with intermediate education) [SL.UEM.INTM.MA.ZS]":"Percentage unemployment"},inplace = True)
in_m


in_f=jobs_statsf[["Time","Sex","Unemployment with intermediate education, female (% of female labor force with intermediate education) [SL.UEM.INTM.FE.ZS]"]]
in_f["Education"]= "intermediate"
in_f.rename(columns = {"Unemployment with intermediate education, female (% of female labor force with intermediate education) [SL.UEM.INTM.FE.ZS]":"Percentage unemployment"},inplace = True)
in_f

af=jobs_statsf[["Time","Sex","Unemployment with advanced education, female (% of female labor force with advanced education) [SL.UEM.ADVN.FE.ZS]"]]
af["Education"]= "advanced"
af.rename(columns = {"Unemployment with advanced education, female (% of female labor force with advanced education) [SL.UEM.ADVN.FE.ZS]":"Percentage unemployment"},inplace = True)
af

edu_mf = pd.concat([af,in_f,in_m,am])
edu_mf

edu_mf.to_csv (r'C:\Users\vaibh\Documents\expo_project\edu_mf.csv', index = False, header=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)	SL.TLF.CACT.FE.ZS
# Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate)	SL.TLF.CACT.MA.ZS
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate)	SL.TLF.CACT.ZS
# Labor force with advanced education (% of total working-age population with advanced education)	SL.TLF.ADVN.ZS
# Labor force with advanced education, female (% of female working-age population with advanced education)	SL.TLF.ADVN.FE.ZS
# Labor force with advanced education, male (% of male working-age population with advanced education)	SL.TLF.ADVN.MA.ZS
# Labor force with basic education (% of total working-age population with basic education)	SL.TLF.BASC.ZS
# Labor force with basic education, female (% of female working-age population with basic education)	SL.TLF.BASC.FE.ZS
# Labor force with basic education, male (% of male working-age population with basic education)	SL.TLF.BASC.MA.ZS
# Labor force with intermediate education (% of total working-age population with intermediate education)	SL.TLF.INTM.ZS
# Labor force with intermediate education, female (% of female working-age population with intermediate education)	SL.TLF.INTM.FE.ZS
# Labor force with intermediate education, male (% of male working-age population with intermediate education)	SL.TLF.INTM.MA.ZS

# %%
force_m= job_stats[["Time",
                    "Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.MA.ZS]"]]

force_f = job_stats[["Time",
                    "Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.FE.ZS]"]]

force_m["Sex"]= "Male"
force_f["Sex"]= "Female"

force_f.rename(columns = {"Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.FE.ZS]":"Labour force percentage"
}, inplace =True)

force_m.rename(columns = {"Labor force participation rate, male (% of male population ages 15+) (modeled ILO estimate) [SL.TLF.CACT.MA.ZS]":"Labour force percentage"
}, inplace =True)

force_mf = pd.concat([force_f,force_m])
force_mf = force_mf.reset_index()
force_mf = force_mf.drop("index",axis =1 )
force_mf
force_mf.to_csv (r'C:\Users\vaibh\Documents\expo_project\force_mf.csv', index = False, header=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
edu_mf
# Out:
#       Time     Sex Percentage unemployment     Education
# 0   1990.0  Female                      ..      advanced
# 1   1991.0  Female                      ..      advanced
# 2   1992.0  Female                      ..      advanced
# 3   1993.0  Female                      ..      advanced
# 4   1994.0  Female                      ..      advanced
# 5   1995.0  Female        2.16000008583069      advanced
# 6   1996.0  Female                      ..      advanced
# 7   1997.0  Female        3.59999990463257      advanced
# 8   1998.0  Female         3.4300000667572      advanced
# 9   1999.0  Female                      ..      advanced
# 10  2000.0  Female        3.90000009536743      advanced
# 11  2001.0  Female        3.47000002861023      advanced
# 12  2002.0  Female        3.51999998092651      advanced
# 13  2003.0  Female        3.83999991416931      advanced
# 14  2004.0  Female        3.36999988555908      advanced
# ...
